# %% [markdown]
# ## **Job Skill Extraction for all Job Market Data in Project**
# - This program will extract job skills from all job posts across all job market platforms (LinkedIn, Workoplis, Indeed and Glassdoor)
# - This serves as a demonstration of how the job skills are extracted from job posts before using job_skill_extraction_model_prediction.py

# %%
# !pip install contractions
# !pip install bert-for-tf2
# !pip install tqdm
# !pip install tensorflow_hub
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.1.68)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.4)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.3.0)
# Requirement already satisfied: bert-for-tf2 in /usr/local/lib/python3.7/dist-packages (0.14.9)
# Requirement already satisfied: py-params>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from bert-for-tf2) (0.10.2)
# Requirement already satisfied: params-flow>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from bert-for-tf2) (0.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from params-flow>=0.8.0->bert-for-tf2) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from params-flow>=0.8.0->bert-for-tf2) (4.63.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.63.0)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_hub) (1.21.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_hub) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorflow_hub) (1.15.0)

# %%
import pandas as pd 
import numpy as np

# Upgrade from TF1 to TF2 for bert implementation
# tensorflow_version 2.8.0
import tensorflow as tf
import tensorflow_hub as hub
import bert
from tensorflow import keras
from tensorflow.keras.layers import Input

# %% [markdown]
# ### Read Job Posts

# %%
colab_used = True
if colab_used:
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
input_path_colab = "/content/drive/MyDrive/SFU/CMPT733/project/"
input_path_lab = ""

input_path = input_path_colab if colab_used else input_path_lab

input_file_folder = "job_market_data/linkedin/"

input_file = "linkedIn_records_2022-03-05 185945.csv"

input_model_folder = "model/"
input_model = "job_skill_extraction_bert.h5"

# %% [markdown]
# ### Pre-processing Job Posts

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.1.68)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.4)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.3.0)

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize, RegexpTokenizer
import contractions
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# !python -m spacy download en_core_web_lg
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Collecting en_core_web_lg==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 248 kB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.63.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.9.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
import spacy
from spacy import displacy
from collections import Counter
from spacy.matcher import Matcher
from spacy.util import filter_spans
from spacy.tokens import Span
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
def data_preparation_preprocessing(df):
    # Data Pre-processing: most processing / transformation part has already done in web scrapping
    df['description'] = df['description'].apply(lambda x: contractions.fix(str(x)))
    import regex as re
    df['description'] = df['description'].str.lower()
    df['description'] = df['description'].apply(lambda x: re.sub(r'[^-\w\d\s\n\.\!\?\;\,\']+', '', x))
    #df['description'] = df['description'].apply(lambda x: re.sub(r'[\.\!\?\;\']+', '.', x))
    df['description'] = df['description'].apply(lambda x: re.sub(r'\n+', '.', x))
    # amp to & and "andor" to "and or"
    df['description'] = df['description'].str.replace(r'\bandor\b', ' and or ')
    df['description'] = df['description'].str.replace(r'\bamp\b', ' and ')
    #df['sentence'] = df['description'].str.split("\n")

    return df

# %%
def data_preparation_postprocessing(df):

    df['text'] = df.text.str.strip().str.strip(".").str.strip().str.strip(",").str.strip().str.strip("-").str.strip()
    df['text'] = df.text.str.strip().str.strip(".").str.strip().str.strip(",").str.strip().str.strip("-").str.strip()

    df['text'] = df['text'].apply(lambda s: s.replace("a ", '', 1) if s.startswith("a ") else s)
    df['text'] = df['text'].apply(lambda s: s.replace("an ", '', 1) if s.startswith("an ") else s)
    df['text'] = df['text'].apply(lambda s: s.replace("this ", '', 1) if s.startswith("this ") else s)
    df['text'] = df['text'].apply(lambda s: s.replace("the ", '', 1) if s.startswith("the ") else s)
    df['text'] = df['text'].apply(lambda s: s[0:len(s)-2] if s.endswith(" a") else s)
    df['text'] = df['text'].apply(lambda s: s[0:len(s)-3] if s.endswith(" an") else s)
    import string
    df['text'] = df['text'].apply(lambda s: ''.join(filter(lambda x: x in string.printable, s)))
    df['text'] = df['text'].apply(lambda s: s.replace(".", ' '))

    df['text'] = df['text'].apply(lambda s: s.replace("a ", '', 1) if s.startswith("a ") else s)
    df['text'] = df['text'].apply(lambda s: s.replace("an ", '', 1) if s.startswith("an ") else s)
    df['text'] = df['text'].apply(lambda s: s.replace("this ", '', 1) if s.startswith("this ") else s)
    df['text'] = df['text'].apply(lambda s: s.replace("the ", '', 1) if s.startswith("the ") else s)
    df['text'] = df['text'].apply(lambda s: s[0:len(s)-2] if s.endswith(" a") else s)
    df['text'] = df['text'].apply(lambda s: s[0:len(s)-3] if s.endswith(" an") else s)
    df['text'] = df['text'].apply(lambda s: ''.join(filter(lambda x: x in string.printable, s)))
    df['text'] = df['text'].apply(lambda s: s.replace(".", ' '))

    return df

# %% [markdown]
# ### Extraction of Identified POS Patterns

# %%
experience_qualifiers = ['previous', 'prior', 'following', 'recent', 'the above', 'past',
                         
                         'proven', 'demonstrable', 'demonstrated', 'relevant', 'significant', 'practical',
                         'essential', 'equivalent', 'desirable', 'required', 'considerable', 'similar',
                         'working', 'specific', 'qualified', 'direct', 'hands on', 'handson', 
                         
                         'strong', 'solid', 'good', 'substantial', 'excellent', 'the right', 'valuable', 'invaluable',
                         
                         'some', 'any', 'none', 'much', 'extensive', 'no', 'more',
                         'your', 'their',
                         'years', 'months',
                         'uk',
                        ]

stopwords = ['a', 'an', '*', '**', '•', 'this', 'the', ':', 'Skills']

experience_qualifier_pattern = rf'\b(?:{"|".join(experience_qualifiers)})\b'

EXP_TERMS = ['experience', 'experienced', 'expertise', 'expert', 'familiar', 'familiarity', 'ability', 'able', 'required', 'is required', 'knowledge', 'understanding']

# extract noun phrase to the left of the keywords using SpaCy's noun_chunks
def extract_noun_phrase(doc, label_list=None):
    label_list = ['experience'] if label_list is None else label_list
    for item in label_list:    
        label = item
        for np in doc.noun_chunks:
            if np[-1].lower_ == label.lower():
                if len(np) > 1:
                    yield label.upper(), np[0].i, np[-1].i
# extract by looking to the right for a preposition (e.g. in/with) and then looking for its object and extracting the whole left subtree
def extract_adp(doc, label_list=None):
    label_list = ['experience'] if label_list is None else label_list
    for item in label_list:
        label = item
        for tok in doc:
            if tok.lower_ == label.lower():
                for child in tok.rights:
                    if child.dep_ == 'prep':
                        for obj in child.children:
                            if obj.dep_ == 'pobj':
                                yield label.upper(), obj.left_edge.i, obj.i+1
# extract by looking for a phrase like "Experience in/with/using" and then the noun phrase
def extract_adp_2(doc, label_list=None):
    label_list = ['experience'] if label_list is None else label_list
    for item in label_list:
        label = item
        for np in doc.noun_chunks:
            start_tok = np[0].i
            if start_tok >= 2 and doc[start_tok - 2].lower_ == label.lower() and doc[start_tok - 1].pos_ == 'ADP':
                yield label.upper(), start_tok, start_tok + len(np)
def get_conjugations(tok):
    new = [tok]
    while new:
        tok = new.pop()
        yield tok
        for child in tok.children:
            if child.dep_ == 'conj':
                new.append(child)
def get_left_span(tok, label='', include=True):
    offset = 1 if include else 0
    idx = tok.i
    while idx > tok.left_edge.i:
        if tok.doc[idx - 1].pos_ in ('NOUN', 'PROPN', 'ADJ', 'X', 'VERB'):
            idx -= 1
        else:
            break
    return label, idx, tok.i+offset
# expanding conjugations
def extract_adp_conj(doc, label_list=['experience']):
    for item in label_list:
        label = item
        for tok in doc:
            if tok.lower_ in EXP_TERMS:
                for child in tok.rights:
                    if child.dep_ == 'prep':
                        for obj in child.children:
                            if obj.dep_ == 'pobj':
                                for conj in get_conjugations(obj):
                                    yield get_left_span(conj, label.upper())
# extract verb followed by an adposition followed by the Noun, e.g Experience dealing with business clients
def extract_verb_maybeadj_noun(doc, label_list=None):
    label_list = ['experience'] if label_list is None else label_list
    for item in label_list:
        label = item
        for tok in doc:
            if tok.lower_ in EXP_TERMS:
                for child in tok.rights:
                    if child.dep_ == 'acl':
                        for gc in child.children:
                            if gc.dep_ == 'prep':
                                for ggc in gc.children:
                                    if ggc.dep_ == 'pobj':
                                        for c in get_conjugations(ggc):
                                            yield get_left_span(c, label.upper())
                            elif gc.dep_ == 'dobj':
                                for c in get_conjugations(gc):
                                    yield get_left_span(c, label.upper())

# %%
def extract_df(df, *extractors, n_max=None, **kwargs):
    if n_max is None:
        n_max = len(df)
    ent_df = pd.DataFrame(list(get_extractions(df.description[:n_max], *extractors, **kwargs)),
                          columns=['text', 'docidx', 'start', 'end', 'label', 'sent_start', 'sent_end'])
    return ent_df.merge(df, how='left', left_on='docidx', right_index=True)
def get_extractions(examples, *extractors, **kwargs):
    # Could use context instead of enumerate
    for idx, doc in enumerate(nlp.pipe(examples, batch_size=100, disable=['ner'])):
        for ent in filter_spans([Span(doc, start, end, label) for extractor in extractors for label, start, end in extractor(doc, **kwargs)]):
            sent = ent.root.sent
            yield ent.text, idx, ent.start, ent.end, ent.label_, sent.start, sent.end

# %% [markdown]
# ### Loading the model building functions

# %% [markdown]
# Tokenization

# %%
class PaddingInputExample(object):
    """Fake example so the num input examples is a multiple of the batch size.
  When running eval/predict on the TPU, we need to pad the number of examples
  to be a multiple of the batch size, because the TPU requires a fixed batch
  size. The alternative is to drop the last batch, which is bad because it means
  the entire output data won't be generated.
  We use this class instead of `None` because treating `None` as padding
  battches could cause silent errors.
  """
    pass

# %%
class InputExample(object):
    """A single training/test example for simple sequence classification."""

    def __init__(self, guid, text_a, text_b=None, label=None):
        """Constructs a InputExample.
    Args:
      guid: Unique id for the example.
      text_a: string. The untokenized text of the first sequence. For single
        sequence tasks, only this sequence must be specified.
      text_b: (Optional) string. The untokenized text of the second sequence.
        Only must be specified for sequence pair tasks.
      label: (Optional) string. The label of the example. This should be
        specified for train and dev examples, but not for test examples.
    """
        self.guid = guid
        self.text_a = text_a
        self.text_b = text_b
        self.label = label

def create_tokenizer_from_hub_module():
    """Get the vocab file and casing info from the Hub module."""
    BertTokenizer = bert.bert_tokenization.FullTokenizer
    bert_layer = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1",
                                trainable=False)
    vocabulary_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
    to_lower_case = bert_layer.resolved_object.do_lower_case.numpy()
    tokenizer = BertTokenizer(vocabulary_file, to_lower_case)

    return tokenizer

def convert_single_example(tokenizer, example, max_seq_length=256):
    """Converts a single `InputExample` into a single `InputFeatures`."""

    if isinstance(example, PaddingInputExample):
        input_ids = [0] * max_seq_length
        input_mask = [0] * max_seq_length
        segment_ids = [0] * max_seq_length
        label = 0
        return input_ids, input_mask, segment_ids, label

    tokens_a = tokenizer.tokenize(example.text_a)
    if len(tokens_a) > max_seq_length - 2:
        tokens_a = tokens_a[0 : (max_seq_length - 2)]

    tokens = []
    segment_ids = []
    tokens.append("[CLS]")
    segment_ids.append(0)
    for token in tokens_a:
        tokens.append(token)
        segment_ids.append(0)
    tokens.append("[SEP]")
    segment_ids.append(0)

    input_ids = tokenizer.convert_tokens_to_ids(tokens)

    # The mask has 1 for real tokens and 0 for padding tokens. Only real
    # tokens are attended to.
    input_mask = [1] * len(input_ids)

    # Zero-pad up to the sequence length.
    while len(input_ids) < max_seq_length:
        input_ids.append(0)
        input_mask.append(0)
        segment_ids.append(0)

    assert len(input_ids) == max_seq_length
    assert len(input_mask) == max_seq_length
    assert len(segment_ids) == max_seq_length

    return input_ids, input_mask, segment_ids, example.label

def convert_examples_to_features(tokenizer, examples, max_seq_length=256):
    """Convert a set of `InputExample`s to a list of `InputFeatures`."""

    input_ids, input_masks, segment_ids, labels = [], [], [], []
    for example in tqdm_notebook(examples, desc="Converting examples to features"):
        input_id, input_mask, segment_id, label = convert_single_example(
            tokenizer, example, max_seq_length
        )
        input_ids.append(input_id)
        input_masks.append(input_mask)
        segment_ids.append(segment_id)
        labels.append(label)
    return (
        np.array(input_ids),
        np.array(input_masks),
        np.array(segment_ids),
        np.array(labels).reshape(-1, 1),
    )

def convert_text_to_examples(texts, labels):
    """Create InputExamples"""
    InputExamples = []
    for text, label in zip(texts, labels):
        InputExamples.append(
            InputExample(guid=None, text_a=" ".join(str(text)), text_b=None, label=label)
        )
    return InputExamples

# %% [markdown]
# Embedding

# %%
class BertModel(object):
    
    def __init__(self):
        
        self.max_len = 18
        bert_path = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1"
        FullTokenizer=bert.bert_tokenization.FullTokenizer
        
        self.bert_module = hub.KerasLayer(bert_path,trainable=True)

        self.vocab_file = self.bert_module.resolved_object.vocab_file.asset_path.numpy()

        self.do_lower_case = self.bert_module.resolved_object.do_lower_case.numpy()

        self.tokenizer = FullTokenizer(self.vocab_file,self.do_lower_case)
        
    def get_masks(self,tokens, max_seq_length):
        return [1]*len(tokens) + [0] * (max_seq_length - len(tokens))

    def get_segments(self,tokens, max_seq_length):
        """Segments: 0 for the first sequence, 1 for the second"""
        segments = []
        current_segment_id = 0
        for token in tokens:
            segments.append(current_segment_id)
            if token == "[SEP]":
                current_segment_id = 1
        return segments + [0] * (max_seq_length - len(tokens))
    
    def get_ids(self,tokens, tokenizer, max_seq_length):
        """Token ids from Tokenizer vocab"""
        token_ids = tokenizer.convert_tokens_to_ids(tokens,)
        input_ids = token_ids + [0] * (max_seq_length-len(token_ids))
        return input_ids
    def create_single_input(self,sentence,maxlen):

        stokens = self.tokenizer.tokenize(sentence)

        stokens = stokens[:maxlen]

        stokens = ["[CLS]"] + stokens + ["[SEP]"]

        ids = self.get_ids(stokens, self.tokenizer, self.max_len)
        masks = self.get_masks(stokens, self.max_len)
        segments = self.get_segments(stokens, self.max_len)

        return ids,masks,segments

    def create_input_array(self,sentences):
        
        input_ids, input_masks, input_segments = [], [], []

        for sentence in tqdm_notebook(sentences,position=0, leave=True):
            ids,masks,segments=self.create_single_input(sentence,self.max_len-2)

            input_ids.append(ids)
            input_masks.append(masks)
            input_segments.append(segments)
            
        tensor = [np.asarray(input_ids, dtype=np.int32), 
                np.asarray(input_masks, dtype=np.int32), 
                np.asarray(input_segments, dtype=np.int32)]
        return tensor

# %%
class PreprocessingBertData():
    
    def prepare_data_x(self,train_sentences):
        x = bert_model_obj.create_input_array(train_sentences)
        return x
    
    def prepare_data_y(self,train_labels):
        y = list()
        for item in train_labels:
            label = item
            y.append(label)
        y = np.array(y)
        return y

# %% [markdown]
# Model Building

# %%
class NetworkModel():
    def __init__(self):
        self.model = None        
        #self.train_data = [train_input_ids, train_input_masks, train_segment_ids]
        #self.train_labels = train_labels
        #self.test_data = [test_input_ids, test_input_masks, test_segment_ids]
        #self.test_labels = test_labels
        
    def bert_model(self,max_seq_length): 
        in_id = Input(shape=(max_seq_length,), dtype=tf.int32, name="input_ids")
        in_mask = Input(shape=(max_seq_length,), dtype=tf.int32, name="input_masks")
        in_segment = Input(shape=(max_seq_length,), dtype=tf.int32, name="segment_ids")
        
        bert_inputs = [in_id, in_mask, in_segment]

        pooled_output, sequence_output = bert_model_obj.bert_module(bert_inputs)
        """
        #x = tf.keras.layers.GlobalAveragePooling1D()(sequence_output)
        x = tf.keras.layers.SpatialDropout1D(0.2)(sequence_output)
        x = tf.keras.layers.LSTM(64, dropout=0.2, recurrent_dropout=0.2),
        pred = tf.keras.layers.Dense(units=1, activation='sigmoid')(x)
        optimizer = tf.keras.optimizers.Adam(lr=0.00001)
        self.model = tf.keras.models.Model(inputs=bert_inputs, outputs=pred)
        self.model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
        """
        
        x = tf.keras.layers.GlobalAveragePooling1D()(sequence_output)
        x = tf.keras.layers.Dense(128, activation='relu')(x)
        x = tf.keras.layers.Dense(64, activation='relu')(x)
        x = tf.keras.layers.Dense(32, activation='relu')(x)
        x = tf.keras.layers.Dense(24, activation='tanh')(x)
        x = tf.keras.layers.Dense(12, activation='relu')(x)
        pred = tf.keras.layers.Dense(1, activation='softplus')(x)
        optimizer = tf.keras.optimizers.Adam(lr=0.00001)
        self.model = tf.keras.models.Model(inputs=bert_inputs, outputs=pred)
        self.model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
        
        
        
        self.model.summary()
    
    def model_train(self,batch_size,num_epoch):
        print("Fitting to Model")
        
        self.model.fit(self.train_data,self.train_labels,epochs=num_epoch,batch_size=batch_size,validation_split=0.2,shuffle=True)
        
        print("Model Training Complete.")
    
    def model_test(self):
        print("Model Testing on Unseen Data")

        self.model.evaluate(self.test_data, self.test_labels)
        
        print("Model Testing Complete.")

    def save_model(self,model_folder,model_name):    
        self.model.save(model_name+".h5", overwrite=True, include_optimizer=True)
        print("Model saved to Model folder.")

    def get_model(self):    
        return self.model
    
    def load_weights(self, path):
        self.model.load_weights(path)
        print("Model weights loaded.")

# %% [markdown]
# ### Loading the Trained Model

# %%
# Build and Load Model


model = None

bert_model_obj = BertModel()

model = NetworkModel()
model.bert_model(bert_model_obj.max_len)

# Load existing model
model.load_weights(input_path+input_model_folder+input_model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 18)]         0           []
#
#  input_masks (InputLayer)       [(None, 18)]         0           []
#
#  segment_ids (InputLayer)       [(None, 18)]         0           []
#
#  keras_layer (KerasLayer)       [(None, 768),        109482241   ['input_ids[0][0]',
#                                  (None, 18, 768)]                 'input_masks[0][0]',
#                                                                   'segment_ids[0][0]']
#
#  global_average_pooling1d (Glob  (None, 768)         0           ['keras_layer[0][1]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          98432       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 24)           792         ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 12)           300         ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            13          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 109,592,114
# Trainable params: 109,592,113
# Non-trainable params: 1
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model weights loaded.

# %% [markdown]
# ### Putting Everything Together

# %%
# Read job posts

df = pd.read_csv(input_path+input_file_folder+input_file)
df.head()

# Pre-processing
source_df = data_preparation_preprocessing(df)

# Extract tokens
extract_exps = [extract_noun_phrase, extract_adp, extract_adp_2, extract_adp_conj, extract_verb_maybeadj_noun]
df_ents = extract_df(source_df, *extract_exps, n_max=source_df.shape[0], label_list=EXP_TERMS)
df_ents_valid = df_ents[(~df_ents.text.str.lower().str.contains(experience_qualifier_pattern)) & # Not a qualifier
                     ~df_ents.text.isin(stopwords)]

input_df = df_ents_valid[["text", "label", "job_title"]]

# Post-processing
input_df = data_preparation_postprocessing(input_df)

# Group text - just in case of any duplication in entries
consolidated_df = input_df[["text", "job_title"]].drop_duplicates()

input_text = consolidated_df.to_numpy()[:, np.newaxis]

# Instantiate tokenizer
tokenizer = create_tokenizer_from_hub_module()

# Convert data to InputExample format
input_examples = convert_text_to_examples(input_text, np.zeros((len(input_text),1)))

# Convert to features
(input_ids, input_masks, segment_ids, labels 
) = convert_examples_to_features(tokenizer,
                                 input_examples,
                                 max_seq_length = 18)

# Extract job skills
save_preds = model.get_model().predict([input_ids, input_masks, segment_ids] )


predictions = pd.DataFrame(dict(list(zip(consolidated_df["text"].to_numpy(), save_preds))))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# Converting examples to features:   0%|          | 0/4025 [00:00<?, ?it/s]
#                                         0
# activities maintain complete     1.057839
# program management teams         1.141757
# people management                0.983358
# work                             0.308582
# complex technical information    0.856499
# ...                                   ...
# electrical utility safety rules  1.152985
# ontario occupational health      1.075840
# safe performance                 0.858716
# safe operation                   0.844824
# types                            0.240731
#
# [2371 rows x 1 columns]

# %%
pd.options.display.max_rows = None

predictions.T
# Out:
#                                                            0
# activities maintain complete                        1.057839
# program management teams                            1.141757
# people management                                   0.983358
# work                                                0.308582
# complex technical information                       0.856499
# concise manner                                      0.745324
# variety                                             0.514437
# deep                                                0.364997
# software development lifecycle                      1.362817
# scrum                                               1.290231
# kanban methodology                                  0.865627
# agile software development                          1.157773
# professional software engineering practices         0.434889
# recruiting                                          0.843316
# technology recruitment                              1.080827
# workday                                             0.637476
# sourcing tools                                      1.486801
# managerial                                          1.077066
# business strategy                                   1.126587
# stakeholder needs                                   0.789783
# related field                                       0.609440
# specialized                                         0.477734
# education                                           0.771783
# experience project management                       0.605756
# north american leading talent management            0.576956
# leaders                                             0.758251
# employees                                           0.276065
# candidates                                          0.671994
# horizontal strategies                               0.910092
# cohesive narrative                                  0.837947
# leading enterprise options                          0.851117
# horizontal teams                                    0.852431
# agile technology                                    1.109331
# candidate                                           0.416176
# expert                                              0.353733
# businessgroup challenges                            0.860824
# subject matter                                      1.077423
# other fields                                        0.303024
# hr systems                                          1.380052
# business concepts                                   0.891224
# focus                                               0.416860
# broad                                               1.031475
# it                                                  0.553385
# domain experience                                   0.875332
# business intelligence                               1.080182
# ability                                             0.477991
# business transformation and system implementation   0.975651
# minimum intermediate level                          0.624597
# excel                                               0.375023
# basic tsql                                          0.905880
# what                                                0.504462
# other fieldsprevious experience                     0.628268
# hr systemsbachelor's degree                         1.136187
# minimal directionbroad                              0.473658
# use                                                 0.381589
# solving                                             1.257018
# critical thinking abilitiesdemonstrated ability     1.025223
# hr preferredminimum intermediate level              1.014251
# wordbasic tsql                                      0.976633
# business                                            0.740874
# positive user                                       0.291534
# workday configuration                               0.687726
# end-to-end hr business processes                    1.017928
# business partners                                   0.995914
# levels                                              0.445973
# ownership                                           0.402571
# financial services industry                         1.298311
# hr project management                               1.448414
# related human resources                             0.955644
# corporate hr                                        0.819877
# difference                                          0.601592
# lasting impact                                      0.752743
# law                                                 0.882420
# solution architecture                               1.373057
# mid                                                 0.434697
# at least 2 functional areas                         0.651353
# sap systems                                         1.397748
#                                                     0.441972
# architecture                                        1.053626
# oil                                                 0.329025
# gas                                                 0.644231
# energy                                              0.643946
# we                                                  0.496528
# date                                                0.575592
# dedicated hr                                        0.889535
# 60 employees                                        0.240505
# progressive hr                                      0.871484
# canadian hr employment law                          0.744480
# global company                                      1.175413
# hr                                                  1.060646
# even better                                         0.457335
# customers                                           0.786437
# customer service associates                         1.004431
# customer                                            0.567932
# culture                                             0.909757
# deep technical                                      0.974552
# better customer                                     0.588473
# everything                                          0.893473
# multiple competing priorities                       0.549828
# paced environment                                   0.406785
# thorough                                            0.413046
# software development                                1.362817
# team                                                0.436959
# large scale systems                                 1.268540
# security engineering                                0.999677
# system                                              1.424890
# network security                                    0.659473
# authentication                                      0.785142
# security protocols                                  1.252332
# cryptography                                        1.085731
# application security amazon                         0.989742
# next iteration                                      0.515841
# qualifications mandatory data integration           0.631022
# complex analysis                                    0.837415
# related                                             0.307280
# product strategyvisionroadmaps                      1.245137
# lean-agile environment                              0.857668
# asset                                               0.597234
# technical                                           0.714318
# agile process                                       1.226611
# principles                                          0.629294
# advance                                             0.831939
# microsoft office                                    1.061349
# information                                         0.650475
# different audiences                                 0.561755
# agile development techniques                        0.898051
# scrum techniques                                    1.040680
# artifacts                                           0.478582
# user stories                                        0.466570
# automated testing                                   0.919741
# backlog refinement                                  0.827713
# clear                                               0.635207
# root                                                0.741328
# industry standard techniques                        1.248339
# minimal direction                                   0.473658
# exercise initiative                                 0.763853
# project management techniques                       1.320716
# condition                                           0.703427
# applicable human rights legislation consistent      1.147851
# delivery                                            0.925667
# millions                                            0.305949
# building and operating web-based applications       1.186787
# massive scale                                       0.790669
# c                                                   0.711313
# java                                                1.229678
# optimization algorithms development                 0.656786
# databases                                           1.193051
# new product development                             0.892605
# employee                                            0.407021
# cross-functional teams                              0.799246
# ambiguity                                           1.053829
# fast paced environment                              0.690752
# openness                                            0.306727
# complex talent                                      0.864938
# human resources                                     1.317522
# organizational concepts                             0.654444
# complex information                                 0.632470
# powerpoint                                          0.599211
# agile mindset                                       1.053977
# talent management                                   1.072219
# talent domains                                      1.286305
# proficient                                          0.740538
# forward thinking talent management                  0.851408
# overall candidate and employee                      0.571377
# technology workforce                                0.662917
# talent and workforce planning                       0.727979
# creation                                            0.771894
# change                                              0.641643
# others                                              0.265212
# technology, business and industry                   0.786943
# account onboarding                                  0.723020
# partnership                                         0.668839
# diverse people management                           0.853259
# consulting environments                             0.871535
# data                                                1.102395
# global                                              0.652794
# leadership                                          0.847609
# syscon product                                      1.343082
# exceptional customer                                0.758193
# big data                                            0.904171
# cloud computing                                     0.899022
# scale distributed systems                           1.070370
# leading role                                        0.856780
# requirements                                        0.654061
# distributed and service-oriented architectures      0.945208
# sales                                               1.076097
# problem-solving                                     0.584925
# analysis                                            1.139818
# organization                                        0.687152
# most pressing business challenges                   1.050806
# life cycle                                          0.275069
# contract inventory data                             0.743121
# service management                                  1.386731
# service integration                                 1.452711
# itil                                                0.320110
# cobit                                               0.373127
# specifically and importantly expert                 0.935883
# multiple tasks                                      0.314357
# teams ability                                       0.414565
# system-level software                               1.257266
# java frameworks                                     0.740812
# design patterns                                     0.678532
# code refactoring                                    0.683264
# oriented architecture                               0.817717
# driven design experience                            0.947277
# restful apis                                        0.425477
# api tools                                           0.578029
# andemerson? our                                     0.560933
# commitment                                          0.559168
# marketplace                                         1.125128
# our                                                 0.568182
# new sectors                                         0.535988
# distributed systems                                 1.248938
# consistent hashing                                  0.626330
# related work                                        0.409077
# each                                                0.239999
# development                                         0.998143
# one                                                 0.266518
# part                                                0.447556
# professional services environment                   0.434889
# financial impact                                    1.063028
# workload                                            0.552987
# values while                                        0.320350
# consistent and exceptional deloitte                 0.668934
# computer science fundamentals                       0.687127
# design architecture                                 1.070608
# reliability                                         0.284857
# scaling                                             1.173383
# non-internship professional software development    0.356152
# programming                                         0.836080
# at least one modern language                        1.076977
# common design paradigms                             0.620245
# other object oriented                               0.818818
# unix or linux platform                              0.660768
# distributed multi-tiered systems                    1.137172
# algorithms                                          0.962752
# optimization mathematics linear programming         0.471218
# runbooks                                            0.573708
# non-technical documentation                         0.439338
# junior software development engineers               1.137806
# code review                                         0.706275
# design review                                       0.806767
# python                                              0.388305
# perl                                                0.536015
# other scripting languages                           0.570661
# distributed advertising software amazon             1.139787
# director                                            0.586460
# project management                                  1.320716
# strategic thinking                                  0.970996
# decisions                                           0.355926
# financial acumen                                    1.319839
# relationships                                       0.887397
# matrix environment                                  0.431141
# industry                                            1.345995
# trusted relationships                               0.782741
# them                                                0.459708
# complex projects                                    1.016478
# french                                              0.590746
# systems integrators                                 1.385008
# third parties                                       0.566983
# cloud transformation programs                       0.981862
# initiatives                                         0.271594
# technology principles                               0.816772
# services                                            0.830908
# aws                                                 0.388854
# property and casualty insurance                     0.913741
# life                                                0.435804
# health insurance                                    0.857335
# wealth management                                   1.236811
# securities brokerage                                1.147859
# asset management                                    1.048003
# venture capital                                     1.031164
# secure                                              1.033709
# edge virtual access methods                         0.910173
# seamless internal customer                          0.950529
# user                                                0.340865
# leadership level presentation                       0.978142
# advice                                              1.141131
# support                                             0.639270
# in-depth                                            0.364243
# businessgroup                                       0.860824
# policies                                            0.319837
# prime subject matter                                0.449466
# internalexternal stakeholders                       0.718057
# better                                              0.330438
# bmos program                                        0.979269
# compensation theory                                 0.772665
# program design methodology                          0.729897
# ground                                              0.893410
# technical program management                        0.915020
# related industry                                    0.879455
# productprogram management                           1.309186
# emerging technologies                               0.690996
# machine learning technologies                       0.871576
# statistical systems                                 1.281641
# alternative erp systems                             1.013140
# client                                              1.225628
# peoplesoft 9 2 hcm                                  0.678204
# fscm                                                0.667085
# business analysis                                   1.307751
# business processes                                  1.138881
# resources the                                       0.416490
# english                                             0.792616
# hospitality                                         0.714831
# client experience                                   0.795888
# office operations                                   0.816770
# facilities management                               0.924101
# executive administrative support                    0.726169
# senior management level                             1.079004
# professional services                               0.434889
# physical office moves                               0.964262
# new office environment                              0.497784
# other managers                                      0.793095
# compugen services                                   0.923976
# delivery management                                 1.351240
# service design related positions                    1.283673
# various service management fields                   0.787415
# itil framework                                      0.390509
# knit team                                           0.293204
# gaming                                              1.046893
# tech                                                0.602951
# hr operations                                       1.004168
# payroll                                             0.351065
# bamboo hr                                           0.955950
# deel                                                0.862743
# trello                                              0.727546
# confluence                                          0.690865
# applicable hr systems fluent                        1.257542
# hr analytics                                        1.219249
# reporting                                           0.716809
# human resources systems                             1.317522
# information management                              0.924375
# analytics                                           1.254407
# processes                                           0.915594
# sap solutions products                              1.332466
# staff                                               0.686486
# public                                              0.868665
# sap hr eccs4hana solution                           1.387651
# program leadership                                  0.959324
# other erp solutions                                 0.845921
# cross-functional team                               0.799246
# sap hr cloud and on-premise implementations         1.248914
# customization experience                            0.749273
# s4 hana transformation                              1.146855
# sap successfactors                                  1.426577
# management role                                     1.051490
# respect                                             0.856316
# multifaceted                                        0.337264
# corporate information technology projects           0.773289
# system development                                  1.124316
# hr business functions                               1.231022
# organization effectiveness                          0.616125
# complex, result-oriented, matrixed, multination...  0.406512
# preferred qualifications                            0.412318
# database systems internals                          1.276102
# query optimization                                  0.886120
# storage systems                                     1.259686
# large-scale data analytics                          1.063226
# data warehousing                                    1.110481
# data structures                                     1.366120
# system performance                                  0.958850
# tasks                                               0.254434
# completion                                          0.593450
# agile development environment                       0.898051
# canadian government sector                          0.741174
# large scale computing solutions                     1.293854
# solutions architect                                 1.253263
# best-practice                                       0.671490
# aws solutions architect community                   1.110537
# 25                                                  1.014697
# needed basic qualifications                         0.660020
# government provincial                               0.943660
# distributed applications                            1.043462
# infrastructure architecture                         1.060275
# database architecture                               1.341159
# networking                                          0.646672
# architectural concepts                              1.167554
# methodologies                                       0.955343
# external organizations                              0.671515
# related industries                                  0.879455
# business leaders                                    1.147942
# other cross functional departments                  0.802414
# system workflow functionality                       0.817659
# kimble or salesforce administration capacity        0.786419
# salesforce                                          1.350873
# professional services software implementation       0.434889
# professional                                        0.371887
# software implementation                             1.121101
# workflow analysisdocumentation                      0.466145
# non-technical audiences                             0.439338
# alumni                                              1.045400
# digital                                             1.129215
# fundamentally different talent                      0.749668
# initiative                                          0.332330
# complex concepts                                    0.602624
# effective manner continuous support                 0.563896
# fairness project management                         0.977248
# best user                                           0.446889
# maximum adoption                                    0.942783
# exceptional technical                               0.529040
# effectively articulate technical challenges         0.564801
# solutions                                           1.184998
# lambda  and ; other aws services                    0.788967
# agile development methodologies                     0.898051
# stretch goals                                       0.415176
# large scale web applications                        1.048096
# recruiting managers                                 0.845411
# peers                                               0.324863
# delivery subject matter                             0.972473
# hr process                                          0.841977
# consulting                                          0.828885
# global fulfillment network                          0.903233
# foundational canada                                 0.779277
# us employment laws                                  0.736156
# broad human resource                                1.289739
# employee relations                                  0.806416
# lululemon delta distribution center                 0.628222
# time                                                0.292420
# average                                             0.635751
# night shift teams                                   0.338611
# director level leadership                           0.801054
# canada and bc labor law and employment equity r...  1.062262
# superior                                            0.431020
# cibc private wealth management                      0.852659
# cibc wood gundys offering                           0.691648
# value-proposition                                   0.958472
# other cibc division                                 0.570617
# investment strategy                                 1.146688
# trust administration                                1.185567
# assets exceptional verbal                           0.856267
# growth                                              1.145705
# investment advisors                                 1.184818
# other key contacts                                  0.587861
# accessible candidate                                0.711694
# professional and technical engineering              0.747537
# work methods design                                 0.957384
# regional and local engineering                      0.689571
# national engineering projects                       0.658946
# various projects                                    0.924387
# engineering                                         0.818904
# other candidate requirements thorough               0.456019
# lean                                                1.088204
# sigma                                               0.963377
# process management                                  1.193588
# query languages                                     1.106557
# six sigma                                           1.145367
# project                                             0.833892
# scoping requirements                                0.863253
# actual launch                                       0.683836
# security                                            1.186978
# authorization mechanism                             0.592476
# service                                             1.091214
# local                                               0.396670
# all hr systems                                      1.185279
# benefits                                            0.648914
# nft related industry leading tools                  0.900891
# familiarity                                         0.412594
# open source tools                                   0.717591
# performance problems performance testing            0.707734
# load                                                0.536246
# automation                                          1.072069
# monitoring tools                                    0.860060
# load test                                           0.687925
# test management tools                               0.962253
# end-end phases                                      0.631634
# code reviews                                        0.759375
# agile environments                                  0.550408
# health                                              0.351701
# health promotion                                    0.964990
# diversity healthcare                                1.162878
# progressive leadership                              0.815783
# healthy environment                                 0.523266
# decision-making responsibilities                    0.340359
# need                                                0.318805
# physical resources                                  0.980533
# partnerships                                        0.775634
# organizational goals                                0.654444
# unionized sector                                    0.839761
# management                                          0.954499
# real-world                                          0.265509
# writing                                             0.712547
# orally                                              0.390636
# professional software development                   0.434889
# big data technologies hadoop                        1.129016
# web latency                                         0.674346
# complex large scale deployments                     0.900887
# big data systems                                    1.325587
# business intelligence products                      1.080182
# deeper                                              0.596814
# market                                              0.716959
# corporate environment                               0.643789
# asset sound                                         0.379148
# adult learning principles                           1.268056
# instructional design                                1.083575
# methods                                             1.011144
# evaluation the                                      0.880614
# all openings                                        0.849981
# ultimate customer service                           0.344829
# sound                                               0.612482
# areas                                               0.331148
# paced development environment                       0.683598
# software development preferred qualifications       1.362817
# web technologies                                    0.921252
# generalist                                          0.865767
# contentious issues                                  0.538966
# all amazon products                                 1.139383
# project delivery                                    0.792895
# user interface development experience   design ...  0.873665
# object oriented design patterns                     0.861227
# true requirements                                   0.421636
# internet protocols                                  0.964708
# web services technologies                           1.007760
# linux development environment                       1.011048
# mentor                                              0.699715
# tech lead                                           0.648729
# leading                                             0.927591
# hands-on                                            0.573299
# large-scale distributed storage and database sy...  0.984411
# os or database internals                            1.293538
# aws cloud product                                   1.101893
# application development                             0.949414
# programming methodologies                           0.685318
# process                                             0.407434
# technical leadership                                0.991023
# agile team environments                             0.900843
# survey design                                       0.982717
# implementation                                      0.735595
# data analysis                                       1.079105
# kpi development                                     0.755735
# spss                                                0.899063
# db pensions                                         0.423425
# multi-task                                          0.249642
# product management                                  1.441400
# audiology                                           0.827081
# compte sur vous pour vos ides et votre              0.768548
# business analyst                                    1.307751
# rdbms                                               0.802327
# power bi                                            0.373152
# dax                                                 1.002205
# vba                                                 0.833945
# regex                                               0.556488
# apis                                                0.939618
# webservices                                         0.756059
# product                                             1.090000
# multiple business environments                      0.896660
# daily engagements apply expert                      1.185490
# netsuite application                                0.750935
# multiple demands                                    0.571068
# training                                            1.295509
# position oracle                                     0.504214
# professional full-time work                         0.547539
# internships                                         0.422358
# exceptional                                         0.282639
# yourself                                            0.652327
# global nature                                       0.952189
# enterprise hr systems support                       1.023100
# continuous improvement                              0.865472
# related roles                                       0.492832
# successfactors                                      0.781574
# matrix organization                                 0.762134
# successfactors jam                                  0.781574
# platform experience                                 0.836852
# cross                                               1.218064
# functional hr system design                         0.885957
# client service skills                               0.945439
# software development processes                      1.362817
# virtual environment                                 0.476836
# multiple countries                                  0.517717
# cultures                                            0.669537
# reports                                             0.654061
# stressful situations                                0.613549
# analytical                                          1.168768
# range                                               0.672767
# continued user                                      0.885053
# our technology solution                             0.702416
# exceptional ey                                      0.463729
# end-to-end product establish                        0.781664
# key subject matter                                  0.947993
# 247 production on-call role                         0.693661
# systems development life cycles                     1.345135
# tools                                               0.287143
# best practices                                      0.711225
# salesforce architecture concerns                    1.474143
# high-performance systems                            0.485506
# service design                                      1.283673
# level technical requirements                        0.782621
# executable project plans                            0.637686
# bachelor's degree                                   0.920747
# every 1 year                                        0.318455
# program management                                  1.141757
# all aspects                                         0.672583
# multi-tiered distributed software systems           0.669511
# oriented architecture projects                      0.817717
# multiple interdisciplinary teams                    0.526187
# software engineering practices                      0.898700
# seamless                                            0.503988
# micro-learnings                                     0.724485
# either communications                               0.453001
# advertising                                         1.180133
# marketing                                           1.022454
# branding                                            0.690938
# journalism                                          0.395050
# e-learning                                          0.567931
# corporate education                                 0.849470
# alexa                                               0.483406
# team environment preferred qualifications           0.291705
# machine learning systems                            0.871576
# remarkable team member                              0.455845
# delivery and exceptional team member                0.916945
# team member                                         0.431851
# at least, one modern programming language           0.616118
# distributed computing and enterprise-wide systems   0.945285
# junior software engineers                           1.137806
# many disparate technologies                         1.201622
# user interfaces                                     0.873665
# frustration-free                                    0.617949
# proficient understanding                            0.918693
# general                                             0.668139
# accessible canada act                               0.711694
# provincial disability policies                      0.998431
# laws                                                0.701374
# intermediate                                        0.367312
# windows                                             0.618255
# word                                                0.291325
# powerpoint preferred qualifications                 0.723374
# advocacy                                            0.887208
# growing environment                                 0.688123
# designing                                           0.824066
# amazon web services                                 0.913372
# junior engineers                                    0.826213
# interns amazon                                      0.727940
# various groups                                      0.457384
# unixlinux operating system                          0.863051
# linux environment                                   0.508026
# oriented architecture techniques                    0.817717
# web development technologies                        0.656151
# dynamic payroll environment                         0.765221
# auditable truth                                     0.826254
# point                                               0.641405
# innate                                              0.420837
# passion                                             0.474133
# software development engineer                       1.362817
# full stack development                              0.781083
# underlying feature requests                         0.785008
# leader                                              0.564263
# successful enterprise-level program management      0.869259
# strategic                                           0.793376
# international coaching federated icf affiliated...  0.965449
# insights                                            0.288611
# talent                                              0.491652
# whole lifecycle value                               0.613406
# human behaviour                                     0.785158
# adequate                                            0.678659
# positions                                           0.321246
# established hr generalist                           0.981648
# technical diagnostic and repair role                1.004527
# experience etl development                          0.721182
# source control                                      1.260611
# environment                                         0.485472
# machine learning                                    0.871576
# sets                                                0.713163
# design issues                                       0.469377
# performance                                         0.471395
# memory                                              0.591066
# io                                                  0.919814
# threading                                           0.745938
# c  understanding                                    0.705640
# asynchronous and distributed systems problems       1.103383
# issues                                              0.273335
# high-volume, highly-available, distributed serv...  0.244465
# humber                                              0.952550
# pressure                                            0.679644
# warm canadian                                       0.875010
# best employee                                       0.304974
# our internal guests                                 0.856774
# leadership role                                     1.065222
# housing supervisor                                  0.574758
# resident assistant                                  0.329816
# compassion                                          0.573199
# patience                                            0.487440
# feet                                                0.278850
# computer equipment                                  0.881725
# technology                                          0.878181
# other hr databases                                  0.892027
# canada please note                                  0.798582
# interview                                           0.496054
# apply button                                        0.816182
# travel                                              0.261111
# continual innovation                                0.797482
# best candidate                                      0.446016
# internal hiring take                                0.539648
# design                                              1.117521
# or                                                  0.551530
# customer experience teams                           0.831676
# high growth environment                             0.479960
# ats tools                                           0.468773
# technologies                                        0.706950
# independent                                         0.485132
# space                                               1.137837
# thousands                                           0.613560
# software security concepts                          1.278020
# software engineering processes                      0.898700
# teams                                               0.340142
# maintanable code                                    1.008515
# diverse                                             0.414244
# ms office products excel                            1.414318
# outlook                                             0.444710
# etc                                                 0.410958
# consulting industry                                 0.974737
# human                                               1.265406
# resources                                           0.315322
# fundamentals                                        0.732347
# scalability                                         0.464575
# team environment                                    0.291705
# top-notch                                           0.435436
# remarkable technical                                0.595984
# non-internship professional software                0.356152
# kubernetes                                          0.523816
# docker                                              1.053476
# cncf ecosystem                                      0.860785
# general   experience                                0.877437
# object-oriented                                     0.779794
# other engineers                                     0.479014
# linux                                               1.048694
# hr disciplines                                      1.349747
# systems                                             1.157373
# enterprise aws development                          0.947449
# servicenow implementations                          1.142287
# experience                                          0.524552
# javascript                                          1.147902
# application experience incident                     0.656243
# integration                                         0.817404
# senior account managers strategic digital           0.932465
# client facing role                                  0.885728
# digital marketing, analytics etc                    1.298057
# omni-channel marketing                              0.756052
# global operations shared                            1.248486
# complete tasks                                      0.459458
# analyses                                            1.173299
# preparation                                         0.572317
# finance                                             0.605328
# investment                                          0.965913
# development and testing methodologies               0.978894
# global compensation theory                          0.970522
# long term incentive plans                           0.632824
# structures                                          0.899290
# technology company                                  0.906854
# performance engineering                             0.626046
# expert level                                        0.360527
# monitoring                                          0.909978
# programming and scripting languages java            0.707188
# jmeter                                              0.353986
# sql performance sets                                0.942459
# software engineering design patterns                0.898700
# anti-patterns                                       0.817062
# udp and web-services                                0.865161
# scale web services                                  0.994577
# itil processes                                      0.812964
# at least two different computing platforms          0.999713
# operating systems                                   1.026426
# environments                                        0.501452
# database technologies                               1.171128
# programming languages                               0.988721
# communication protocols experience                  0.660974
# middleware                                          0.760669
# gateways knowledge                                  0.804630
# systems analysis                                    1.379908
# metadata structures                                 0.921006
# repository functions                                0.531840
# data dictionaries experience                        1.095470
# e g  models awareness                               0.999410
# object-oriented analysis                            0.779794
# design techniques experience                        0.763143
# information management principles                   0.924375
# later, solaris, windows, aix and linux              0.493744
# decision making processes                           0.529246
# change management and release management            1.153545
# automated testing tools                             0.919741
# quality control and assurance methodologies         0.927208
# practices                                           0.756826
# preferred                                           0.443085
# outbound calling                                    0.594589
# energy industry                                     0.886255
# leading internal projects                           0.775363
# particularly the                                    0.898041
# ...
# licenses                                            0.524352
# other limited interest                              0.623871
# class 5 driving                                     1.265553
# long term care facility                             0.859101
# head nurse                                          0.636524
# senior management                                   1.079004
# cantonese                                           0.693643
# mandarin                                            1.102522
# retail pharmacy setting                             0.923391
# hospital retail pharmacy                            1.277116
# chemotherapeutic agents                             1.089059
# operating engineer's                                0.805114
# heating                                             0.799511
# basic electrical                                    1.112918
# computers                                           0.808279
# keyboarding                                         0.871937
# primary care                                        0.419898
# community health                                    0.974087
# postpartum nursing                                  0.891198
# minimal postpartum                                  0.965581
# new technologies                                    0.813675
# access                                              0.255971
# smooth interview                                    0.979097
# both students                                       0.711228
# employers                                           0.558262
# experience administrative                           0.758439
# academic setting                                    0.911614
# technological solutions                             0.902953
# company work practices                              0.686888
# operating rules                                     0.725148
# pertinent ohsa regulations                          0.896577
# electrical utility safety rules                     1.152985
# ontario occupational health                         1.075840
# safe performance                                    0.858716
# safe operation                                      0.844824
# types                                               0.240731

# %%
# Convert to desired format for saving
consolidated_df['prediction_prob'] = save_preds
consolidated_df['predicted_skill'] = (consolidated_df['prediction_prob'] >= 0.5).astype('int8')

consolidated_df
# Out:
#                                                    text  \
# 0                          activities maintain complete
# 1                              program management teams
# 2                                     people management
# 3                                                  work
# 6                         complex technical information
# 7                                        concise manner
# 8                                               variety
# 9                                                  deep
# 10                       software development lifecycle
# 11                                                scrum
# 12                                   kanban methodology
# 13                           agile software development
# 14          professional software engineering practices
# 15                                           recruiting
# 16                               technology recruitment
# 17                                              workday
# 18                                       sourcing tools
# 19                                           managerial
# 23                                    business strategy
# 24                                    stakeholder needs
# 26                                        related field
# 27                                          specialized
# 28                                            education
# 29                        experience project management
# 32             north american leading talent management
# 33                                              leaders
# 34                                            employees
# 35                                           candidates
# 36                                horizontal strategies
# 37                                   cohesive narrative
# 39                           leading enterprise options
# 41                                     horizontal teams
# 43                                     agile technology
# 44                                            candidate
# 45                                               expert
# 46                             businessgroup challenges
# 48                                    business strategy
# 49                                    stakeholder needs
# 50                                       subject matter
# 53                                         other fields
# 55                                           hr systems
# 57                                    business concepts
# 58                                                focus
# 59                                                broad
# 60                                                   it
# 61                                    domain experience
# 63                                business intelligence
# 64                                              ability
# 66    business transformation and system implementation
# 67                           minimum intermediate level
# 68                                                excel
# 69                                           basic tsql
# 70                                                 what
# 72                      other fieldsprevious experience
# 73                          hr systemsbachelor's degree
# 76                               minimal directionbroad
# 83                                                  use
# 84                                              solving
# 85      critical thinking abilitiesdemonstrated ability
# 86               hr preferredminimum intermediate level
# 88                                       wordbasic tsql
# 90                                    business strategy
# 91                                    stakeholder needs
# 93                                        related field
# 95                                                 deep
# 96                                             business
# 98                                        positive user
# 99                                       subject matter
# 101                               workday configuration
# 103                    end-to-end hr business processes
# 105                                   business partners
# 106                                              levels
# 107                                           ownership
# 108                                                work
# 109                         financial services industry
# 110                               hr project management
# 111                             related human resources
# 112                                        corporate hr
# 113                                          difference
# 114                                      lasting impact
# 115                                                 law
# 116                               solution architecture
# 117                                                 mid
# 118                                                deep
# 119                         at least 2 functional areas
# 120                                         sap systems
# 121
# 123                                        architecture
# 124                                                 oil
# 125                                                 gas
# 126                                              energy
# 136                                                  we
# 138                                                date
# 141                                        dedicated hr
# 142                                        60 employees
# 143                                      progressive hr
# 144                          canadian hr employment law
# 146                                      global company
# 147                                                  hr
# 149                                         even better
# 150                                           customers
# 152                         customer service associates
# 153                                            customer
# 154                                             culture
# 155                                      deep technical
# 156                                     better customer
# 157                                          everything
# 158                                   people management
# 163                       complex technical information
# 164                                             variety
# 166                       multiple competing priorities
# 167                                   paced environment
# 168                                            thorough
# 169                                software development
# 170                                                team
# 171                                 large scale systems
# 172                                security engineering
# 173                                              system
# 174                                    network security
# 175                                      authentication
# 176                                  security protocols
# 177                                        cryptography
# 178                         application security amazon
# 179                                      next iteration
# 180           qualifications mandatory data integration
# 181                                    complex analysis
# 182                                             related
# 185
# 186                      product strategyvisionroadmaps
# 187                              lean-agile environment
# 188                                               asset
# 189                                               scrum
# 190                                           technical
# 191                                       agile process
# 192                                          principles
# 194                                             advance
# 195                                    microsoft office
# 198                                         information
# 200                                 different audiences
# 201                        agile development techniques
# 202                                    scrum techniques
# 203                                           artifacts
# 204                                        user stories
# 205                                   automated testing
# 206                                  backlog refinement
# 207                                               clear
# 208                                                root
# 209                        industry standard techniques
# 211                                   minimal direction
# 212                                 exercise initiative
# 213                       project management techniques
# 214                                           condition
# 215      applicable human rights legislation consistent
# 216                                            delivery
# 217                                            millions
# 218       building and operating web-based applications
# 219                                       massive scale
# 221                                                   c
# 222                                                java
# 226                 optimization algorithms development
# 227                                           databases
# 228
# 229                             new product development
# 230                                            employee
# 232                              cross-functional teams
# 233                                           ambiguity
# 234                              fast paced environment
# 235                                            openness
# 236                                      complex talent
# 237                                     human resources
# 238                             organizational concepts
# 240                                 complex information
# 241                                               excel
# 242                                          powerpoint
# 244                                       agile mindset
# 246                                   talent management
# 247                                      talent domains
# 248                                          proficient
# 249                  forward thinking talent management
# 250                      overall candidate and employee
# 251                                technology workforce
# 252                       talent and workforce planning
# 253                                            creation
# 255                                              change
# 257                                              others
# 258                   technology, business and industry
# 259                                  account onboarding
# 260                                         partnership
# 262                           diverse people management
# 263                             consulting environments
# 264                                                data
# 265                                              global
# 266                                          leadership
# 285                                      subject matter
# 286                                      syscon product
# 287                                      deep technical
# 288                                exceptional customer
# 290                                software development
# 291                                            delivery
# 292                                            big data
# 293                                     cloud computing
# 294                           scale distributed systems
# 295                       complex technical information
# 296                                      concise manner
# 297                                             variety
# 298                                        leading role
# 299                                        requirements
# 300                                                deep
# 301      distributed and service-oriented architectures
# 302                       multiple competing priorities
# 303                                   paced environment
# 316                                               sales
# 318                                     problem-solving
# 319                                            analysis
# 320                                        organization
# 321                   most pressing business challenges
# 323                                          life cycle
# 324
# 325                                                  it
# 326                             contract inventory data
# 327                                                work
# 329                                  service management
# 330                                 service integration
# 331                                                itil
# 332                                               cobit
# 333                                          principles
# 334                 specifically and importantly expert
# 335                                               excel
# 337                                      multiple tasks
# 338                                       teams ability
# 340                               system-level software
# 342                                     java frameworks
# 344                                     design patterns
# 345                                    code refactoring
# 346                               oriented architecture
# 347                            driven design experience
# 348                                        restful apis
# 349                                           api tools
# 350                                     andemerson? our
# 351                                          commitment
# 352                                         marketplace
# 353                                                 our
# 354                                         new sectors
# 357                                   people management
# 358                                software development
# 359
# 360                                 distributed systems
# 361                                  consistent hashing
# 362                                        related work
# 365                                             related
# 367                                                each
# 368
# 369                                         development
# 370                                                 one
# 373                                                part
# 375                   professional services environment
# 377                                    financial impact
# 378                                            workload
# 379                                        values while
# 380                 consistent and exceptional deloitte
# 383                       computer science fundamentals
# 385                                 design architecture
# 386                                     design patterns
# 387                                         reliability
# 388                                             scaling
# 389    non-internship professional software development
# 390                                         programming
# 391                        at least one modern language
# 392                             common design paradigms
# 393                                                java
# 394                               other object oriented
# 395                              unix or linux platform
# 396                    distributed multi-tiered systems
# 397                                          algorithms
# 398         optimization mathematics linear programming
# 399                                            runbooks
# 400                                           technical
# 401                         non-technical documentation
# 402               junior software development engineers
# 403                                         code review
# 404                                       design review
# 405                                              python
# 406                                                perl
# 407                           other scripting languages
# 409             distributed advertising software amazon
# 410                                            director
# 411                                  project management
# 412                                           ownership
# 413                                  strategic thinking
# 414                                        requirements
# 415                                           decisions
# 416
# 417                                    financial acumen
# 418                                       relationships
# 420                                  matrix environment
# 423                                            industry
# 425                               trusted relationships
# 427                                                them
# 428                                    complex projects
# 431                                            customer
# 432                                              french
# 433                                  project management
# 435                                 systems integrators
# 436                                       third parties
# 437                       cloud transformation programs
# 438                                         initiatives
# 439                               technology principles
# 440                                            services
# 441                                                 aws
# 442                     property and casualty insurance
# 443                                                life
# 444                                    health insurance
# 445                                   wealth management
# 446                                            services
# 447                                securities brokerage
# 448                                    asset management
# 449                                     venture capital
# 450                                              secure
# 451                         edge virtual access methods
# 454                                        organization
# 456                                              french
# 457                          seamless internal customer
# 458                                                user
# 459                       leadership level presentation
# 460                                              advice
# 461                                             support
# 462                                            in-depth
# 463                                       businessgroup
# 464                                      subject matter
# 466                                            policies
# 468                                prime subject matter
# 469                       internalexternal stakeholders
# 471                                   business strategy
# 472                                   stakeholder needs
# 473                                              better
# 474                                        bmos program
# 476                                       related field
# 477                                              expert
# 478                                 compensation theory
# 479                          program design methodology
# 480                                            industry
# 482                                      deep technical
# 483                                              ground
# 484                                exceptional customer
# 486                        technical program management
# 487                                    related industry
# 488                           productprogram management
# 489                               emerging technologies
# 490                       machine learning technologies
# 491                                 statistical systems
# 492                                            big data
# 494                             alternative erp systems
# 495                                              client
# 497                                  peoplesoft 9 2 hcm
# 498                                                fscm
# 499                                   business analysis
# 500                                  business processes
# 501                                       resources the
# 502                                             support
# 503                                              french
# 504                                             english
# 506                                   business strategy
# 507                                   stakeholder needs
# 509                                       related field
# 511                                                deep
# 512                                            business
# 514                                         hospitality
# 515                                   client experience
# 516                                   office operations
# 517                               facilities management
# 518                    executive administrative support
# 519                             senior management level
# 520                               professional services
# 522                               physical office moves
# 523                              new office environment
# 525                                      other managers
# 527                 consistent and exceptional deloitte
# 529                                   compugen services
# 531                                 delivery management
# 532                               solution architecture
# 533                    service design related positions
# 534                   various service management fields
# 536                                      itil framework
# 538                                           knit team
# 539                                              gaming
# 540                                                tech
# 541                                             related
# 542                                       hr operations
# 543                                             payroll
# 544                                           bamboo hr
# 545                                                deel
# 546                                              trello
# 547                                          confluence
# 548                                              change
# 549                        applicable hr systems fluent
# 550                                      subject matter
# 551                                        hr analytics
# 552                                           reporting
# 553                                             related
# 554                             human resources systems
# 555                              information management
# 556                                           analytics
# 559                                           processes
# 560                              sap solutions products
# 561                                              client
# 563                                               staff
# 564                                              public
# 566                           sap hr eccs4hana solution
# 567                                  program leadership
# 568                                 other erp solutions
# 570                               cross-functional team
# 572         sap hr cloud and on-premise implementations
# 573                            customization experience
# 574                              s4 hana transformation
# 575                                  sap successfactors
# 576                                     management role
# 577                                             respect
# 578                                        multifaceted
# 579           corporate information technology projects
# 580                                  system development
# 581                                   business analysis
# 582                               hr business functions
# 583                                           processes
# 584                          organization effectiveness
# 585   complex, result-oriented, matrixed, multinatio...
# 599    non-internship professional software development
# 600                                         programming
# 601                        at least one modern language
# 602                                 design architecture
# 603                                     design patterns
# 604                                         reliability
# 605                                             scaling
# 606                            preferred qualifications
# 608                          database systems internals
# 609                                  query optimization
# 610                                     storage systems
# 611                          large-scale data analytics
# 612                                    data warehousing
# 614                                     data structures
# 615                                  system performance
# 617                                               tasks
# 618                                          completion
# 619                       agile development environment
# 620                                                deep
# 621                          canadian government sector
# 623                     large scale computing solutions
# 625                                 solutions architect
# 627                                       best-practice
# 628                   aws solutions architect community
# 629                                                  25
# 630                         needed basic qualifications
# 631                               government provincial
# 633                            distributed applications
# 635                         infrastructure architecture
# 636                               database architecture
# 637                                          networking
# 638                              architectural concepts
# 639                                       methodologies
# 641                              external organizations
# 642                                software development
# 643                                  related industries
# 645    non-internship professional software development
# 646                                         programming
# 647                        at least one modern language
# 648                                 design architecture
# 649                                     design patterns
# 650                                         reliability
# 651                                             scaling
# 652                                      subject matter
# 653                                    business leaders
# 654                  other cross functional departments
# 656                       system workflow functionality
# 658        kimble or salesforce administration capacity
# 659                                          salesforce
# 661       professional services software implementation
# 662                                        professional
# 663                             software implementation
# 664                      workflow analysisdocumentation
# 666                             non-technical audiences
# 667                                              alumni
# 668                                             digital
# 669                      fundamentally different talent
# 671                                          initiative
# 673                                    complex concepts
# 674                 effective manner continuous support
# 675                         fairness project management
# 676                 consistent and exceptional deloitte
# 677                                           best user
# 678                                    maximum adoption
# 679                               exceptional technical
# 680    non-internship professional software development
# 681                                         programming
# 682                        at least one modern language
# 683                                 design architecture
# 684                                     design patterns
# 685                                         reliability
# 686                                             scaling
# 689                    distributed multi-tiered systems
# 690         effectively articulate technical challenges
# 691                                           solutions
# 692                    lambda  and ; other aws services
# 693                     agile development methodologies
# 694                                       stretch goals
# 695                              fast paced environment
# 697                        large scale web applications
# 698         professional software engineering practices
# 699
# 700                                          recruiting
# 701                                          candidates
# 702                                 recruiting managers
# 703                                               peers
# 704                                      sourcing tools
# 705                             delivery subject matter
# 707                                          hr process
# 708                                          consulting
# 709                                             culture
# 710                                            employee
# 711                          global fulfillment network
# 712                                         partnership
# 714                                 foundational canada
# 715                                  us employment laws
# 716                                broad human resource
# 717                                            delivery
# 720                                                deep
# 721                                  employee relations
# 722                 lululemon delta distribution center
# 724                                                time
# 726                                             average
# 727                                   night shift teams
# 729                           director level leadership
# 730                                             culture
# 731                                            employee
# 732                          global fulfillment network
# 733                                         partnership
# 735                                                deep
# 736   canada and bc labor law and employment equity ...
# 737                                broad human resource
# 738                                            delivery
# 742                                  employee relations
# 743                 lululemon delta distribution center
# 745                                                time
# 747                                             average
# 748                                   night shift teams
# 749                                            superior
# 750                      cibc private wealth management
# 751                           cibc wood gundys offering
# 752                                            services
# 753                                   value-proposition
# 754                                 other cibc division
# 755                                   wealth management
# 757                                 investment strategy
# 758                                trust administration
# 761                           assets exceptional verbal
# 762                                              growth
# 763                                 investment advisors
# 764                                  other key contacts
# 765                                accessible candidate
# 766              professional and technical engineering
# 767                                            delivery
# 768                                 work methods design
# 769                      regional and local engineering
# 770                       national engineering projects
# 771                                    various projects
# 772                                         engineering
# 773                                                 use
# 774                                        related work
# 775               other candidate requirements thorough
# 776                                                lean
# 777                                               sigma
# 778                                  process management
# 780                                     query languages
# 781
# 782                                              others
# 784                                           six sigma
# 789                                software development
# 790         professional software engineering practices
# 791                                             project
# 792                                scoping requirements
# 793                                       actual launch
# 794                                            security
# 795                                      authentication
# 796                             authorization mechanism
# 797                                             service
# 799                                               local
# 801                                      all hr systems
# 802                                            employee
# 803                                            benefits
# 805                  nft related industry leading tools
# 806                                         familiarity
# 807                                   open source tools
# 808            performance problems performance testing
# 809                                                load
# 810                                          automation
# 811                                    monitoring tools
# 812                                           load test
# 813                               test management tools
# 814                                      end-end phases
# 815                                        code reviews
# 816                                     design patterns
# 817                                  agile environments
# 818                                           condition
# 819      applicable human rights legislation consistent
# 820                                  project management
# 821                                              health
# 822                                    health promotion
# 823                                       related field
# 824                                diversity healthcare
# 825                              progressive leadership
# 826                                 healthy environment
# 828                                     management role
# 830                    decision-making responsibilities
# 832                                                need
# 833                                  physical resources
# 835                                        partnerships
# 836                                organizational goals
# 837                                    unionized sector
# 840                                          management
# 841                                          real-world
# 844                                             writing
# 845                                              orally
# 846                   professional software development
# 847                                         programming
# 848                        at least one modern language
# 849                                 design architecture
# 850                                     design patterns
# 851                                         reliability
# 852                                             scaling
# 853                        big data technologies hadoop
# 854         professional software engineering practices
# 855                                             project
# 856                                scoping requirements
# 857                                       actual launch
# 858
# 859                                         web latency
# 860                     complex large scale deployments
# 861                                           databases
# 862                                           analytics
# 863                                    big data systems
# 864                      business intelligence products
# 865                                          candidates
# 866                                              deeper
# 867                                              market
# 869                               corporate environment
# 870                                         asset sound
# 871                           adult learning principles
# 872                                instructional design
# 873                                             methods
# 874                                      evaluation the
# 876                                        all openings
# 877                           ultimate customer service
# 879                                          initiative
# 880                                            customer
# 882                                               sound
# 883                                               areas
# 885                       paced development environment
# 887       software development preferred qualifications
# 889                                software development
# 890                                    web technologies
# 892                                          generalist
# 893
# 894                                  contentious issues
# 897                                 all amazon products
# 898                                software development
# 900                                                java
# 902                                    project delivery
# 903   user interface development experience   design...
# 904                     object oriented design patterns
# 906                                   true requirements
# 907                                           technical
# 909                   professional software development
# 910                                         programming
# 911                        at least one modern language
# 912                                 design architecture
# 913                                     design patterns
# 914                                         reliability
# 915                                             scaling
# 916                                  internet protocols
# 917                           web services technologies
# 918                       linux development environment
# 919                                 design architecture
# 920                                     design patterns
# 921                                         reliability
# 922                                             scaling
# 923                                         programming
# 924                        at least one modern language
# 925                   professional software development
# 926                                              mentor
# 927                                           tech lead
# 928                                             leading
# 929                                            hands-on
# 930         professional software engineering practices
# 931
# 932   large-scale distributed storage and database s...
# 934                            os or database internals
# 935                                   aws cloud product
# 937                                                java
# 939                             application development
# 940                                         development
# 941                           programming methodologies
# 943                                             process
# 944                                technical leadership
# 945                             agile team environments
# 947                                       survey design
# 948                                      implementation
# 949                                       data analysis
# 950                                     kpi development
# 951                                           reporting
# 953                                                spss
# 956                                         db pensions
# 958                                          multi-task
# 960                                  product management
# 962                                           audiology
# 963              compte sur vous pour vos ides et votre
# 965                                    business analyst
# 968                                               rdbms
# 969                                            power bi
# 970                                                 dax
# 971                                                 vba
# 972                                               regex
# 973                                                apis
# 974                                         webservices
# 976                                             product
# 978                      multiple business environments
# 979                                              deeper
# 982                      daily engagements apply expert
# 983                                netsuite application
# 985                                    multiple demands
# 986                                            training
# 987                                     position oracle
# 988                         professional full-time work
# 989                                         internships
# 992                                           technical
# 1006                                        exceptional
# 1007                                           yourself
# 1008                                               user
# 1009                                      global nature
# 1011                      enterprise hr systems support
# 1012                             continuous improvement
# 1013                                      related roles
# 1014                                     successfactors
# 1015
# 1016                                matrix organization
# 1018                                 successfactors jam
# 1019                                          reporting
# 1020                                platform experience
# 1021                                              cross
# 1022                        functional hr system design
# 1023                              client service skills
# 1024                     software development processes
# 1025                                virtual environment
# 1026                                 multiple countries
# 1027                                              areas
# 1028                                           cultures
# 1030                                            reports
# 1032                               stressful situations
# 1034                                         analytical
# 1035                                              range
# 1036                                     continued user
# 1037                            our technology solution
# 1038                                     exceptional ey
# 1057                                          technical
# 1058                       end-to-end product establish
# 1059                                 key subject matter
# 1060                        247 production on-call role
# 1063                    systems development life cycles
# 1064                                              tools
# 1065                                          processes
# 1066                                     best practices
# 1068                   salesforce architecture concerns
# 1070                                         salesforce
# 1091                           high-performance systems
# 1092                                     service design
# 1094                       level technical requirements
# 1095                           executable project plans
# 1097                                  bachelor's degree
# 1098                                               work
# 1099                                       every 1 year
# 1100                                 program management
# 1101                                        all aspects
# 1102          multi-tiered distributed software systems
# 1103                     oriented architecture projects
# 1105                   multiple interdisciplinary teams
# 1106                                       professional
# 1107                               software development
# 1108                                               deep
# 1109                     software engineering practices
# 1110                                           seamless
# 1111                                    micro-learnings
# 1112                                           employee
# 1113                              either communications
# 1114                                        advertising
# 1115                                          marketing
# 1116                                           branding
# 1117                                         journalism
# 1118                                         e-learning
# 1119                                corporate education
# 1120                                              alexa
# 1121                                design architecture
# 1122                                    design patterns
# 1123                                        reliability
# 1124                                            scaling
# 1125                                        programming
# 1126                       at least one modern language
# 1127                  professional software development
# 1128                                             mentor
# 1129                                          tech lead
# 1130                                            leading
# 1132                                               java
# 1134                                    data structures
# 1135                                         algorithms
# 1136                                           customer
# 1138          team environment preferred qualifications
# ...
# 5622        0.441299         0.441299
# 5623        0.408521         0.408521
# 5624        0.374499         0.374499
# 5625        1.359404         1.359404
# 6136        1.119486         1.119486
# 6137        0.867146         0.867146
# 6139        1.073355         1.073355
# 6142        0.807780         0.807780
# 6143        0.799102         0.799102
# 6144        0.469082         0.469082
# 6145        0.339630         0.339630
# 6146        0.938232         0.938232
# 6148        1.359404         1.359404
# 6150        0.348599         0.348599
# 6151        0.797016         0.797016
# 6152        1.068789         1.068789
# 6153        0.471763         0.471763
# 6155        0.611842         0.611842
# 6156        0.650475         0.650475
# 6157        0.690492         0.690492
# 6158        0.735969         0.735969
# 6159        0.518613         0.518613
# 6160        0.319678         0.319678
# 6165        0.374499         0.374499
# 6166        1.359404         1.359404
# 6167        0.987246         0.987246
# 6168        0.797016         0.797016
# 6169        1.068789         1.068789
# 6170        0.471763         0.471763
# 6172        0.690492         0.690492
# 6173        0.611842         0.611842
# 6174        0.650475         0.650475
# 6176        0.735969         0.735969
# 6177        0.701590         0.701590
# 6178        0.319678         0.319678
# 6180        0.854107         0.854107
# 6181        0.776709         0.776709
# 6182        1.138769         1.138769
# 6184        0.302792         0.302792
# 6185        0.699847         0.699847
# 6186        0.348319         0.348319
# 6187        0.873757         0.873757
# 6188        0.839517         0.839517
# 6189        0.974087         0.974087
# 6190        0.399556         0.399556
# 6191        1.040225         1.040225
# 6192        0.441972         0.441972
# 6193        1.091821         1.091821
# 6195        0.808279         0.808279
# 6196        0.871937         0.871937
# 6197        0.419898         0.419898
# 6198        0.974087         0.974087
# 6199        0.491744         0.491744
# 6200        0.611829         0.611829
# 6201        0.519657         0.519657
# 6203        0.891198         0.891198
# 6204        0.965581         0.965581
# 6205        0.406785         0.406785
# 6206        1.147851         1.147851
# 6207        1.147851         1.147851
# 6208        0.813675         0.813675
# 6210        1.061349         1.061349
# 6211        0.291325         0.291325
# 6212        0.255971         0.255971
# 6213        1.157373         1.157373
# 6214        0.689233         0.689233
# 6215        0.539208         0.539208
# 6216        0.979097         0.979097
# 6217        0.711228         0.711228
# 6218        0.558262         0.558262
# 6219        0.758439         0.758439
# 6220        0.911614         0.911614
# 6223        0.511516         0.511516
# 6225        0.902953         0.902953
# 6226        0.427152         0.427152
# 6228        0.582852         0.582852
# 6230        0.961094         0.961094
# 6231        0.593393         0.593393
# 6233        0.582852         0.582852
# 6234        0.686888         0.686888
# 6235        1.046447         1.046447
# 6236        0.725148         0.725148
# 6237        0.668598         0.668598
# 6238        0.896577         0.896577
# 6239        1.152985         1.152985
# 6240        1.075840         1.075840
# 6241        0.858716         0.858716
# 6243        0.844824         0.844824
# 6246        0.240731         0.240731

# %% [markdown]
# ### Other References

# %%
def data_process(chunks):
    '''creates a dataframe that easily parses the chunks data 
    '''
    df = pd.DataFrame(chunks)    
    df.fillna('X', inplace = True)
    
    pattern = []
    for row in df.values:
        phrase = ''
        for tup in row:
            # needs a space at the end for seperation
            phrase += tup[0] + ' '
        phrase = ''.join(phrase)
        # could use padding tages but encoder method will provide during 
        # tokenizing/embeddings; X can replace paddding for now
        pattern.append( phrase.replace('X', '').strip())
    df['phrase'] = pattern
    # only returns 10% of each dataframe to be used 
    return df.phrase
